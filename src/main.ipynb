# %%
import numpy as np  # import auxiliary library, typical idiom
import pandas as pd  # import the Pandas library, typical idiom

# next command ensures that plots appear inside the notebook
from statsmodels.compat import pandas
# %matplotlib inline
import math
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = 10, 5  # default hor./vert. size of plots, in inches
plt.rcParams['lines.markeredgewidth'] = 1  # to fix issue with seaborn box plots; needed after import seaborn

import seaborn as sns

sns.set()
from sklearn.linear_model import LinearRegression  # for linear regression

import statsmodels.api as sm

# %% [markdown]
# Data needs to be entered in csv, beacuse it is easier to work with and to "mine" it.

# %%
"""data_read = pd.read_csv('path/to/data')
Path needs to be the litteral path to to the files aka from home to files
data_read.head()"""
seedsData = pd.read_csv('~/PycharmProjects/47Entrepeneur/datasets/seeds.csv')
seedsData.head()
# Out:
#     area  perimeter  kernel_length  kernel_width  asymmetry  groove_length
# 0  15.26      14.84          5.763         3.312      2.221          5.220
# 1  14.88      14.57          5.554         3.333      1.018          4.956
# 2  14.29      14.09          5.291         3.337      2.699          4.825
# 3  13.84      13.94          5.324         3.379      2.259          4.805
# 4  16.14      14.99          5.658         3.562      1.355          5.175

# %%
"""For the stripplot"""

sns.stripplot(data=seedsData, x='asymmetry', y='perimeter')
# Out:
# <AxesSubplot:xlabel='asymmetry', ylabel='perimeter'>

# %% [markdown]
# For heatmap first make it a matrix, and then it can be plotted as a heatmap.
